# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c = pd.read_csv("CountyWide.csv")
c
# Out:
#         County  Rural1960  College2000  College1990  College1980  Jobs1990
# 0      Autauga          0        0.180        0.145        0.121     11471  \
# 1      Baldwin          0        0.231        0.168        0.121     40809
# 2      Barbour          1        0.109        0.118        0.092     12163
# 3         Bibb          1        0.071        0.047        0.049      5564
# 4       Blount          1        0.096        0.070        0.053     11811
# ..         ...        ...          ...          ...          ...       ...
# 62  Tuscaloosa          0        0.240        0.200        0.166     76838
# 63      Walker          0        0.091        0.072        0.064     26136
# 64  Washington          1        0.086        0.067        0.055      7176
# 65      Wilcox          1        0.101        0.103        0.095      5421
# 66     Winston          1        0.083        0.054        0.052     11986
#
# ...

# %%
c1 = c[c["County"]=="Autauga"]
print(c1)
c1[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]]
# Out:
#     County  Rural1960  College2000  College1990  College1980  Jobs1990
# 0  Autauga          0         0.18        0.145        0.121     11471  \
#
#    Jobs1980  Jobs2000  College1970  College1960  ...  ContigJobsK1960
# 0     11278     16289     0.063557      0.04396  ...         21.67713  \
#
#    ContigJobsK1970  ContigJobsK1980  ContigJobsK1990  ContigJobsK2000
# 0         22.65133           27.652         32.55667         38.40267  \
#
#    Mobil1950  College1950  Pop1950   LFP1950  HWY1950
# 0   0.190929     0.028852    18186  0.509641        0
#
# [1 rows x 48 columns]
#    Jobs1960  Jobs1970  Jobs1980  Jobs1990  Jobs2000
# 0      4911      6853     11278     11471     16289

# %%
c2= c[c["County"]=="Baldwin"]
print(c2)
c2[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]]
# Out:
#     County  Rural1960  College2000  College1990  College1980  Jobs1990
# 1  Baldwin          0        0.231        0.168        0.121     40809  \
#
#    Jobs1980  Jobs2000  College1970  College1960  ...  ContigJobsK1960
# 1     27861     70247     0.064649     0.050063  ...         32.24768  \
#
#    ContigJobsK1970  ContigJobsK1980  ContigJobsK1990  ContigJobsK2000
# 1          31.3664           41.983          46.0588          54.1814  \
#
#    Mobil1950  College1950  Pop1950   LFP1950  HWY1950
# 1   0.215782      0.03427    40997  0.507535        0
#
# [1 rows x 48 columns]
#    Jobs1960  Jobs1970  Jobs1980  Jobs1990  Jobs2000
# 1     15577     19749     27861     40809     70247

# %%
c3= c[c["County"]=="Barbour"]
print(c3)
c3[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]]
# Out:
#     County  Rural1960  College2000  College1990  College1980  Jobs1990
# 1  Baldwin          0        0.231        0.168        0.121     40809  \
#
#    Jobs1980  Jobs2000  College1970  College1960  ...  ContigJobsK1960
# 1     27861     70247     0.064649     0.050063  ...         32.24768  \
#
#    ContigJobsK1970  ContigJobsK1980  ContigJobsK1990  ContigJobsK2000
# 1          31.3664           41.983          46.0588          54.1814  \
#
#    Mobil1950  College1950  Pop1950   LFP1950  HWY1950
# 1   0.215782      0.03427    40997  0.507535        0
#
# [1 rows x 48 columns]
#    Jobs1960  Jobs1970  Jobs1980  Jobs1990  Jobs2000
# 1     15577     19749     27861     40809     70247

# %%
c4= c[c["County"]=="Bibb"]
print(c4)
c4[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]]
# Out:
#   County  Rural1960  College2000  College1990  College1980  Jobs1990
# 3   Bibb          1        0.071        0.047        0.049      5564  \
#
#    Jobs1980  Jobs2000  College1970  College1960  ...  ContigJobsK1960
# 3      4276      6098     0.041863     0.032528  ...         57.57091  \
#
#    ContigJobsK1970  ContigJobsK1980  ContigJobsK1990  ContigJobsK2000
# 3         62.93667         76.72433         91.67717        109.92483  \
#
#    Mobil1950  College1950  Pop1950   LFP1950  HWY1950
# 3   0.196791     0.016929    17987  0.433244        0
#
# [1 rows x 48 columns]
#    Jobs1960  Jobs1970  Jobs1980  Jobs1990  Jobs2000
# 3      4108      3965      4276      5564      6098

# %%
c5= c[c["County"]=="Blount"]
print(c5)
c5[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]]
# Out:
#    County  Rural1960  College2000  College1990  College1980  Jobs1990
# 4  Blount          1        0.096         0.07        0.053     11811  \
#
#    Jobs1980  Jobs2000  College1970  College1960  ...  ContigJobsK1960
# 4      9490     16503     0.026672     0.024412  ...         60.65395  \
#
#    ContigJobsK1970  ContigJobsK1980  ContigJobsK1990  ContigJobsK2000
# 4           66.805         81.69067           95.233          110.588  \
#
#    Mobil1950  College1950  Pop1950   LFP1950  HWY1950
# 4   0.252402     0.019465    28975  0.479702        0
#
# [1 rows x 48 columns]
#    Jobs1960  Jobs1970  Jobs1980  Jobs1990  Jobs2000
# 4      6710      7587      9490     11811     16503

# %%
print(c5[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]].to_numpy().shape)
print(c5[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]].to_numpy())
#plt.plot(c5[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])
#plt.scatter([1,2,3,4,5],[6710,7587,9490,11811, 16503])
plt.scatter([1,2,3,4,5],c5[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])
plt.scatter([1,2,3,4,5],c4[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])
plt.scatter([1,2,3,4,5],c3[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])
plt.scatter([1,2,3,4,5],c2[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])
plt.scatter([1,2,3,4,5],c1[["Jobs1960","Jobs1970","Jobs1980","Jobs1990","Jobs2000"]])

plt.show()
# Out:
# (1, 5)
# [[ 6710  7587  9490 11811 16503]]

# %%
from sklearn.linear_model import LinearRegression
#calc the average y in each position for single regression line
#each color needs a separate regression line? 
y=[np.mean(c5[["Jobs1960")]],np.mean(),np.mean(),np.mean(),np.mean()]

# %%
import numpy as np

print(c5["Jobs1960"])
print(c4["Jobs1960"])
y1=(np.mean([c5["Jobs1960"],c4["Jobs1960"],c3["Jobs1960"],c2["Jobs1960"],c1["Jobs1960"]]))
y2=(np.mean([c5["Jobs1970"],c4["Jobs1970"],c3["Jobs1970"],c2["Jobs1970"],c1["Jobs1970"]]))
y3=(np.mean([c5["Jobs1980"],c4["Jobs1980"],c3["Jobs1980"],c2["Jobs1980"],c1["Jobs1980"]]))
y4=(np.mean([c5["Jobs1990"],c4["Jobs1990"],c3["Jobs1990"],c2["Jobs1990"],c1["Jobs1990"]]))
y5=(np.mean([c5["Jobs2000"],c4["Jobs2000"],c3["Jobs2000"],c2["Jobs2000"],c1["Jobs2000"]]))
y=np.array([y1,y2,y3,y4,y5])
x=[1,2,3,4,5]
print(y.shape)
reg = LinearRegression().fit(x, y.reshape(-1,1))
score(reg)
# Out:
# 4    6710
# Name: Jobs1960, dtype: int64
# 3    4108
# Name: Jobs1960, dtype: int64
# (5,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 13
#      11 x=[1,2,3,4,5]
#      12 print(y.shape)
# ---> 13 reg = LinearRegression().fit(x, y.reshape(-1,1))
#      14 score(reg)
#
# File ~/test_stuff/repeated_measures/test_anova/.venv/lib/python3.10/site-packages/sklearn/linear_model/_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
# ...
