# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c = pd.read_csv("CountyWide.csv")
c
# need 2 windoes, have to open these up in numbers and the other browser window in teh dataset description
# Out:
#         County  Rural1960  College2000  College1990  College1980  Jobs1990
# 0      Autauga          0        0.180        0.145        0.121     11471  \
# 1      Baldwin          0        0.231        0.168        0.121     40809
# 2      Barbour          1        0.109        0.118        0.092     12163
# 3         Bibb          1        0.071        0.047        0.049      5564
# 4       Blount          1        0.096        0.070        0.053     11811
# ..         ...        ...          ...          ...          ...       ...
# 62  Tuscaloosa          0        0.240        0.200        0.166     76838
# 63      Walker          0        0.091        0.072        0.064     26136
# 64  Washington          1        0.086        0.067        0.055      7176
# 65      Wilcox          1        0.101        0.103        0.095      5421
# 66     Winston          1        0.083        0.054        0.052     11986
#
# ...

# %%
#which variable is subject? Each county 
#Are there any between-subjects factors?
#Are there any within-subjects factors? Do they have unique values per trial?
#Are there any time-varying covariates?
#Are there any time-invariant covariates?
#For each predictor variable in the data set, indicate if it is measured at level 1 or level 2.
#For each combination of factors, indicate if the factors are crossed or nested. If nested, which is nested in which?
#List all the factors in the table below and all the interactions for the crossed factors. 
#Now check off whether each variable or interaction is fixed or random. 
#(Really, if you haven’t listed to the webinar on Fixed or Random effects, do it now).
#

# %%
pt = pd.read_csv("Physical-training.csv")
pt
# Out:
#     group  age  height  BM_pre  BM_post     BF_pre    BF_post     FM_pre
# 0       1   23     170      67     66.0  16.592290  10.679237  11.116834  \
# 1       1   25     169      75     74.0  24.454803  21.742614  18.341102
# 2       1   23     184      65     64.5  10.871363   9.247212   7.066386
# 3       1   25     181      83     83.0  21.330883  19.752134  17.704632
# 4       1   26     172      84     82.0  24.762802  22.305996  20.800754
# 5       1   25     184      76     73.5  13.280854  10.446214  10.093449
# 6       1   27     176      65     64.0  21.228522  21.743747  13.798539
# 7       1   23     172      58     59.0  15.139682  15.715843   8.781016
# 8       1   26     170      68     65.0  20.921894  19.729293  14.226888
# 9       2   24     169      80     81.0  10.997114  10.547350   8.797691
# 10      2   27     175      70     70.0  24.225130  21.475022  16.957591
# 11      2   24     169      55     55.5   7.728282   7.077390   4.250555
# ...

# %%
#which variable is subject? Each row, id in header missing, assume id
Tricky have to separate the predictors from the random variable. group/age/height are predictors
#Are there any between-subjects factors? categorical predictors which does not change with time
groups, 
#Are there any within-subjects factors? Do they have unique values per trial?
#Are there any time-varying covariates? bmi, all the floating point numbers
#Are there any time-invariant covariates? maybe height and age. Better to make age/height categorical to restrict
the range of the values. No such thing as 0 height and we are bounded in height and age. 
#For each predictor variable in the data set, indicate if it is measured at level 1 or level 2.
#For each combination of factors, indicate if the factors are crossed or nested. If nested, which is nested in which?
#List all the factors in the table below and all the interactions for the crossed factors. 
#Now check off whether each variable or interaction is fixed or random. 
#(Really, if you haven’t listed to the webinar on Fixed or Random effects, do it now).
#

# %%
sw = pd.read_csv("Swallowing.csv")
sw
# Out:
#      ParticipantID Sex    Task  Trial Bulb  AMAXTPreference
# 0              Y02   F   AHMAX      1    A              461  \
# 1              Y02   F   AHMAX      1    P              461
# 2              Y02   F   AHMAX      2    A              461
# 3              Y02   F   AHMAX      2    P              461
# 4              Y02   F   AHMAX      3    A              461
# ...            ...  ..     ...    ...  ...              ...
# 2275           Y33   M  PMAXTP      3    P              492
# 2276           Y33   M  PMAXTP      4    A              492
# 2277           Y33   M  PMAXTP      4    P              492
# 2278           Y33   M  PMAXTP      5    A              492
# 2279           Y33   M  PMAXTP      5    P              492
#
#       AmplitudeRangeTransformedmmHg  RiseTime  ReleaseTime    RiseSlope
# 0                        285.032538     483.0        534.0   590.129478  \
# 1                         31.236443     167.0        183.0   187.044566
# ...

# %%
#which variable is subject? ParticipandID. 
#Are there any between-subjects factors?
#Are there any within-subjects factors? Do they have unique values per trial?
#Are there any time-varying covariates?
#Are there any time-invariant covariates?
#For each predictor variable in the data set, indicate if it is measured at level 1 or level 2.
#For each combination of factors, indicate if the factors are crossed or nested. If nested, which is nested in which?
#List all the factors in the table below and all the interactions for the crossed factors. 
#Now check off whether each variable or interaction is fixed or random. 
#(Really, if you haven’t listed to the webinar on Fixed or Random effects, do it now).
#

# %%
teachers = pd.read_csv("Teachers.csv")
teachers
# Out:
#     SubID  Gender   Age  Grade  SES  TeacherID    t0Know  t0TchExp    PIS
# 0       1     2.0   9.0    4.0  2.0        5.0 -0.231350  2.857143  2.875  \
# 1       2     1.0  11.0    6.0  2.0       12.0 -0.003201  3.142857  7.250
# 2       3     2.0  10.0    6.0  2.0       13.0  0.356242  3.142857  4.125
# 3       4     1.0  10.0    5.0  2.0        8.0  1.751254  2.857143  2.875
# 4       5     2.0  11.0    6.0  2.0       15.0 -0.933597  3.571429  6.500
# ..    ...     ...   ...    ...  ...        ...       ...       ...    ...
# 79     80     2.0   9.0    4.0  2.0        4.0 -0.933597  2.857143  8.875
# 80     81     2.0   9.0    4.0  2.0        3.0 -0.933597  3.428571  3.000
# 81     82     2.0  10.0    5.0  2.0        9.0  0.219353  4.000000  6.500
# 82     83     1.0  10.0    5.0  2.0        7.0 -0.003201  3.428571  5.750
# 83     84     1.0   NaN    5.0  2.0        7.0       NaN       NaN  5.750
#
#     Rapport.1  Rapport.2  Rapport.3  STRS.1  STRS.2  STRS.3
# ...

# %%
#which variable is subject? 
#Are there any between-subjects factors? between-subject is categorical and measured once. not a repeat. 
#gender, age, ses, grade, teacherID, 
#Are there any within-subjects factors? Categorical measured repeat, STRS1-3 
#Are there any time-varying covariates? Real valued, repeat, Rapport1-3
#Are there any time-invariant covariates? Real valued measured not repeat t0Know, t0TchExp, PIS
#For each predictor variable in the data set, indicate if it is measured at level 1 or level 2.

#For each combination of factors, indicate if the factors are crossed or nested. If nested, which is nested in which?

#List all the factors in the table below and all the interactions for the crossed factors. 
#Now check off whether each variable or interaction is fixed or random.

# %%
infant = pd.read_csv("infant.csv")
infant
# Out:
#      subject  weeks  breath  percITD  percETD  percITE  percETE  percITslope
# 0          1  52.71       1   84.720   90.284   98.808   99.935      114.367  \
# 1          1  52.71       1   96.325  119.431  114.536   99.240      121.741
# 2          1  52.71       1  102.128  113.744  111.894  111.381      108.069
# 3          1  52.71       1  118.375   91.706  100.403   94.682       81.992
# 4          1  52.71       1   95.164   92.417   94.567  100.381       98.218
# ..       ...    ...     ...      ...      ...      ...      ...          ...
# 288        9  90.00       3  125.000  138.577  199.141  113.814      165.979
# 289        9  90.00       3   67.935  175.094  128.392  153.031      189.506
# 290        9  90.00       3   95.109  180.712  162.224  183.746      164.484
# 291        9  90.00       3   80.163  116.105   83.312  190.657      109.566
# 292        9  90.00       3   99.185  128.277  127.004  142.993      140.018
#
#      percETslope   uttdur   dBSPL
# ...

# %%
#which variable is subject? infants, 292
#Are there any between-subjects factors? between-subject is categorical and measured once. subject id
#Are there any within-subjects factors? Categorical measured repeat,   breath
#Are there any time-varying covariates? Real valued, repeat, percITD, percETD, percTSlope, percETslope, uttdur dbSPL
#Are there any time-invariant covariates? Real valued measured not repeat; weeks
#For each predictor variable in the data set, indicate if it is measured at level 1 or level 2.

#For each combination of factors, indicate if the factors are crossed or nested. If nested, which is nested in which?

#List all the factors in the table below and all the interactions for the crossed factors. 
#Now check off whether each variable or interaction is fixed or random.
