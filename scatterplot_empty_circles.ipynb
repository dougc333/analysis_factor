# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

fig, axs = plt.subplots(2, 3, sharex=True, sharey=True)
# marker symbol
#where is facecolors and edgecolors in the docs? under 
axs[0, 0].scatter(x, y, facecolors='none', edgecolors='r')
axs[0, 0].set_title("marker='o'")
# Out:
# Text(0.5, 1.0, "marker='o'")

# %%
import seaborn as sns
import pandas as pd

birth=pd.read_csv("/Users/dc/analysis_factor/datasets_irc_workshop/BIRTH.csv")
