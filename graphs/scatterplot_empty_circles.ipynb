# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

fig, axs = plt.subplots(2, 3, sharex=True, sharey=True)
# marker symbol
#where is facecolors and edgecolors in the docs? under 
axs[0, 0].scatter(x, y, facecolors='none', edgecolors='r')
axs[0, 0].set_title("marker='o'")
# Out:
# Text(0.5, 1.0, "marker='o'")

# %%
import pandas as pd
import seaborn as sns
#
nlsy = pd.read_csv("/Users/dc/analysis_factor/datasets_irc_workshop/NLSY.csv")
nlsy=nlsy.dropna()
nlsy.head()
# Out:
#     R0000100  PCS2000 CESD2000Total CESDTotal2000cutpt  MCS2000  \
# 13       242   6663.0             8                  1    760.0
# 14      9320   6592.0            12                  1    951.0
# 15      2886   6437.0            12                  1   1026.0
# 16      9672   6464.0            19                  1   1074.0
# 17     12588   6543.0            18                  1   1298.0
#
#     RelAt2000cat6 RelAt2000cat2  Gender  Race3 Marital2000c5  Education2000  \
# 13              2             1       1      3             4             12
# 14              6             2       1      2             5             14
# 15              4             1       1      2             3             13
# 16              2             1       1      2             4             16
# 17              5             1       1      2             5             12
#
#     Education2000c4  NumberBioStepAdoptChildHH2000  BioChildHH2000c2  \
# ...

# %%
sns.lmplot(x='MCS2000',y='PCS2000',data=nlsy,fit_reg=True)

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = nlsy.iloc[:, 1].values.reshape(-1, 1)  # iloc[:, 1] is the column of X
Y = nlsy.iloc[:, 4].values.reshape(-1, 1)  # df.iloc[:, 4] is the column of Y
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

plt.scatter(X, Y,facecolors='none', edgecolors='blue')
plt.plot(X, Y_pred, color='red')
plt.show()
